# %% [markdown]
# <a href="https://colab.research.google.com/github/DarkerizOp/workco/blob/main/ML_MODEL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
df=pd.read_csv("/content/drive/MyDrive/ML_Practice/CarPrice_Assignment")
df
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
df.isnull().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
# Label Encoding --> For changing the column datas in string data type to integer
from sklearn.preprocessing import LabelEncoder
categorical_cols=["CarName",	"fueltype",	"aspiration",	"doornumber",	"carbody",	"drivewheel",	"enginelocation", "fuelsystem", "enginetype", "cylindernumber"]
en=LabelEncoder()
for col in categorical_cols:
  df[col]=en.fit_transform(df[col])
df
# Out:
#      car_ID  symboling  CarName  fueltype  aspiration  doornumber  carbody  \
# 0         1          3        2         1           0           1        0
# 1         2          3        3         1           0           1        0
# 2         3          1        1         1           0           1        2
# 3         4          2        4         1           0           0        3
# 4         5          2        5         1           0           0        3
# ..      ...        ...      ...       ...         ...         ...      ...
# 200     201         -1      139         1           0           0        3
# 201     202         -1      138         1           1           0        3
# 202     203         -1      140         1           0           0        3
# 203     204         -1      142         0           1           0        3
# 204     205         -1      143         1           1           0        3
#
# ...

# %%
x=df.iloc[:,1:-1].values
x
# Out:
# array([[ 3.00e+00,  2.00e+00,  1.00e+00, ...,  5.00e+03,  2.10e+01,
#          2.70e+01],
#        [ 3.00e+00,  3.00e+00,  1.00e+00, ...,  5.00e+03,  2.10e+01,
#          2.70e+01],
#        [ 1.00e+00,  1.00e+00,  1.00e+00, ...,  5.00e+03,  1.90e+01,
#          2.60e+01],
#        ...,
#        [-1.00e+00,  1.40e+02,  1.00e+00, ...,  5.50e+03,  1.80e+01,
#          2.30e+01],
#        [-1.00e+00,  1.42e+02,  0.00e+00, ...,  4.80e+03,  2.60e+01,
#          2.70e+01],
#        [-1.00e+00,  1.43e+02,  1.00e+00, ...,  5.40e+03,  1.90e+01,
#          2.50e+01]])

# %%
y=df.iloc[:,-1].values
y
# Out:
# array([13495.   , 16500.   , 16500.   , 13950.   , 17450.   , 15250.   ,
#        17710.   , 18920.   , 23875.   , 17859.167, 16430.   , 16925.   ,
#        20970.   , 21105.   , 24565.   , 30760.   , 41315.   , 36880.   ,
#         5151.   ,  6295.   ,  6575.   ,  5572.   ,  6377.   ,  7957.   ,
#         6229.   ,  6692.   ,  7609.   ,  8558.   ,  8921.   , 12964.   ,
#         6479.   ,  6855.   ,  5399.   ,  6529.   ,  7129.   ,  7295.   ,
#         7295.   ,  7895.   ,  9095.   ,  8845.   , 10295.   , 12945.   ,
#        10345.   ,  6785.   ,  8916.5  ,  8916.5  , 11048.   , 32250.   ,
#        35550.   , 36000.   ,  5195.   ,  6095.   ,  6795.   ,  6695.   ,
#         7395.   , 10945.   , 11845.   , 13645.   , 15645.   ,  8845.   ,
#         8495.   , 10595.   , 10245.   , 10795.   , 11245.   , 18280.   ,
#        18344.   , 25552.   , 28248.   , 28176.   , 31600.   , 34184.   ,
#        35056.   , 40960.   , 45400.   , 16503.   ,  5389.   ,  6189.   ,
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
m=model.coef_
m
# Out:
# array([ 2.82055665e+02, -2.79991435e+01,  4.28206674e+03,  1.07680239e+03,
#        -1.65075698e+03, -9.47611813e+02,  1.20823269e+03,  1.36912712e+04,
#         1.62921757e+02, -3.62401365e+01,  6.41330367e+02,  1.08151190e+02,
#         3.99430610e+00,  1.45678927e+02,  8.72419901e+01,  7.02385648e+01,
#         4.75947039e+01, -2.01117537e+03, -2.85018993e+03,  3.56525533e+02,
#         1.30591524e+01,  1.26751143e+00,  2.72767031e+01, -2.00807244e+01])

# %%
c=model.intercept_
c
# Out:
# np.float64(-60983.649051366796)

# %%
y_pred=model.predict(x_test)
y_pred
# Out:
# array([ 6066.21443403, 16991.49388357, 14099.07692262,  1690.73764977,
#         9688.25642169, 12981.63154037,  7065.22981668,  4548.28228167,
#        20223.97956341,  8034.31150557, 16142.23856107, 27043.69018579,
#        10651.19042984, 13781.5371498 ,  7536.75201722, 11550.74769025,
#         8736.05774456, 20333.0299429 ,  9670.9649313 ,  6753.1277166 ,
#        10779.00407151, 20128.17687965,  8767.46523773, 12509.81016328,
#        19289.91569501,  6903.27424612,  5847.64869806, 20603.64675442,
#         7223.07702508,  6763.08755208,  6847.84045465,  9631.49613471,
#        16743.77450664,  8764.98176772,  6481.63062022, 24265.35216806,
#         9103.62472146, 14649.97142137,  7050.68735452, 36992.76025734,
#         6056.24913533])

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error
mae=mean_absolute_error(y_test,y_pred)
mse=mean_squared_error(y_test,y_pred)
rmse=(mse**0.5)
print("Mean Absolute Error:",mae)
print("Mean Squared Error:",mse)
print("Root Mean Squared Error:",rmse)
# Out:
# Mean Absolute Error: 2530.407642946725
# Mean Squared Error: 14606686.08022666
# Root Mean Squared Error: 3821.8694483494146

# %%
import matplotlib.pyplot as plt
plt.hist(df['price'],bins=30,edgecolor='black')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.title('Distribution of Car Prices')
plt.show()

# %%
# Actual Price vs Predicted Price Graph
plt.scatter(y_test,y_pred,edgecolor='r')
plt.xlabel('Actual Price')
plt.ylabel('Predicted Price')
plt.title('Actual Price vs Predicted Price')
plt.show()
